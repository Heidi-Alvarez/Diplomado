# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# Lectura de una base de datos en Internet y asignación a la variable datos.
path = "https://raw.githubusercontent.com/diplomado-bigdata-machinelearning-udea/Curso1/master/s02/multiTimeline.csv"
datos = pd.read_csv(path, skiprows=1)

# %%
datos.columns = ['mes', 'dieta', 'gimnasio', 'finanzas']
datos.head()
# Out:
#        mes  dieta  gimnasio  finanzas
# 0  2004-01    100        31        48
# 1  2004-02     75        26        49
# 2  2004-03     67        24        47
# 3  2004-04     70        22        48
# 4  2004-05     72        22        43

# %%
datos.mes = pd.to_datetime(df.mes)
datos.set_index('mes', inplace=True) #inplace para que reemplace el DataFrame original
datos.head()
# Out:
#             dieta  gimnasio  finanzas
# mes
# 2004-01-01    100        31        48
# 2004-02-01     75        26        49
# 2004-03-01     67        24        47
# 2004-04-01     70        22        48
# 2004-05-01     72        22        43

# %%
## Graficamos para tener una idea del comportamiento

datos.plot(figsize=(10,5),linewidth=3, fontsize=20) 
# figsize para el tamaño del cuadro, el primer número es el tamaño horizontal y el segundo el vertical
# linewidth para el tamaño de la línea de la curva
# fontsize para el tamaño de la escala

plt.xlabel('Año', fontsize=15) # para el nombre del eje horizontal
# Out:
# Text(0.5, 0, 'Año')

# %%
## Para graficar cada una de las columnas de manera independiente 

datos[["dieta"]].plot(figsize = (10,5), linewidth = 2, fontsize = 10)
plt.xlabel("Año", fontsize = 10)
datos[["gimnasio"]].plot(figsize = (10,5), linewidth = 2, fontsize = 10)
plt.xlabel("Año", fontsize = 10)
datos[["finanzas"]].plot(figsize = (10,5), linewidth = 2, fontsize = 10)
plt.xlabel("Año", fontsize = 10)
# Out:
# Text(0.5, 0, 'Año')

# %%
## Para comparar por pares

datos[["dieta", "gimnasio"]].plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año", fontsize =10)
datos[["finanzas","dieta"]].plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año", fontsize = 10)
datos[["gimnasio", "finanzas"]].plot(figsize = (10, 5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año", fontsize = 10)
# Out:
# Text(0.5, 0, 'Año')

# %%
## Identificando tendencias

datos.rolling(3).mean().head()   ## Hace el promedio con los datos anteriores. Se llama promedio móvil
# Out:
#                 dieta   gimnasio  finanzas
# mes
# 2004-01-01        NaN        NaN       NaN
# 2004-02-01        NaN        NaN       NaN
# 2004-03-01  80.666667  27.000000      48.0
# 2004-04-01  70.666667  24.000000      48.0
# 2004-05-01  69.666667  22.666667      46.0

# %%
## Veamos este método (promedio móvil) con diferentes números de datos
## Comencemos con Dieta

datos[["dieta"]].rolling(3).mean().plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año 3", fontsize = 10)

datos[["dieta"]].rolling(6).mean().plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año 6", fontsize = 10)

datos[["dieta"]].rolling(12).mean().plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año 12", fontsize = 10)
# Out:
# Text(0.5, 0, 'Año 12')

# %%
## Comencemos con Gimnasio

datos[["gimnasio"]].rolling(3).mean().plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año 3", fontsize = 10)

datos[["gimnasio"]].rolling(7).mean().plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año 6", fontsize = 10)

datos[["gimnasio"]].rolling(10).mean().plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año 12", fontsize = 10)
# Out:
# Text(0.5, 0, 'Año 12')

# %%
## Comencemos con Finanzas

datos[["finanzas"]].rolling(3).mean().plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año 3", fontsize = 10)

datos[["finanzas"]].rolling(6).mean().plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año 6", fontsize = 10)

datos[["finanzas"]].rolling(12).mean().plot(figsize = (10,5) , linewidth = 3 , fontsize = 10)
plt.xlabel("Año 12", fontsize = 10)
# Out:
# Text(0.5, 0, 'Año 12')

# %%
## Método de diferenciación: calcula diferencias entre datos consecutivos

datos.dieta.diff().plot(figsize = (10,5) , linewidth = 1.5 , fontsize = 10)
plt.xlabel("Año", fontsize = 10)
# Out:
# Text(0.5, 0, 'Año')

# %%
datos.gimnasio.diff().plot(figsize = (10,5) , linewidth = 1.5 , fontsize = 10)
plt.xlabel("Año", fontsize = 10)
# Out:
# Text(0.5, 0, 'Año')

# %%
datos.finanzas.diff().plot(figsize = (10,5) , linewidth = 1.5 , fontsize = 10)
plt.xlabel("Año", fontsize = 10)
# Out:
# Text(0.5, 0, 'Año')
